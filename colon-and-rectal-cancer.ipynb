# %%
## Import libraries

import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix,classification_report

# %%
## I use 64x64 grayscale images represented into a CSV

data = pd.read_csv("../input/hmnist_64_64_L.csv")

# %%
## Let's look the data

data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  ...    pixel4094  pixel4095  label
# 0        134         99        119  ...          140        195      2
# 1         55         64         74  ...           68         69      2
# 2        114        116        136  ...           89        122      2
# 3         86         82         88  ...           63         48      2
# 4        168        143        140  ...          158        149      2
#
# [5 rows x 4097 columns]

# %%
## Let's look the shape

data.shape
# Out:
# (5000, 4097)

# %%
# Splitting labels and features

Y = data["label"]
data.drop(["label"],axis=1, inplace=True)
X = data

# %%
# And creating a countplot

plt.figure(figsize=(15,7))
g = sns.countplot(Y, palette="winter_r")
plt.suptitle("Amount of each classes")
plt.show()

# %%
## The dataset is well balanced (probably perfect)

Y.value_counts()
# Out:
# 7    625
# 3    625
# 6    625
# 2    625
# 5    625
# 1    625
# 8    625
# 4    625
# Name: label, dtype: int64

# %%
## Manual scaling

X = X / 255.0

# %%
## Looking for an example image

img = X.iloc[75].as_matrix()
img = img.reshape(64,64)
plt.imshow(img)
plt.suptitle("An example of image on the dataset")
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
## Reshaping images for the CNN

X = X.values.reshape(-1,64,64,1)     
Y = Y.values

# %%
## Label Encoding into One-Hot

from keras.utils.np_utils import to_categorical 
Y = to_categorical(Y)

# %%
## Train and test splitting

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

# %%
## Printing shapes

print("X_train.shape: ",X_train.shape)
print("X_test.shape: ",X_test.shape)
print("y_train.shape: ",y_train.shape)
print("y_test.shape: ",y_test.shape)
# Out:
# X_train.shape:  (4000, 64, 64, 1)
# X_test.shape:  (1000, 64, 64, 1)
# y_train.shape:  (4000, 9)
# y_test.shape:  (1000, 9)

# %% [markdown]
# <h1> CNN CREATION

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(filters = 128, kernel_size = (5,5),padding = 'same',activation ='relu', input_shape = (64,64,1)))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(filters = 64, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Conv2D(filters = 64, kernel_size = (3,3),padding = 'same',activation ='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.25))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(256,activation = "relu"))          
model.add(tf.keras.layers.Dense(64,activation = "relu"))
model.add(tf.keras.layers.Dense(32,activation = "relu"))

model.add(tf.keras.layers.Dense(9, activation = "softmax"))

# %%
## Let's print the summary of the model

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 64, 64, 128)       3328
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               1048832
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 9)                 297
# =================================================================
# Total params: 1,181,705
# Trainable params: 1,181,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
## And compile it

model.compile(optimizer = "Adam" , loss = "binary_crossentropy", metrics=["accuracy"])

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=0.5, 
        zoom_range = 0.5, 
        width_shift_range=0.5,  
        height_shift_range=0.5, 
        horizontal_flip=True, 
        vertical_flip=True)

datagen.fit(X_train)

# %%
## Model training

EPOCHS = 50
BATCH_SIZE = 32


hist = model.fit_generator(datagen.flow(X_train,y_train, batch_size=BATCH_SIZE),
                              epochs = EPOCHS, validation_data = (X_test,y_test))
# Out:
# Epoch 1/50
# 125/125 [==============================] - 6s 50ms/step - loss: 0.2765 - acc: 0.8897 - val_loss: 0.2195 - val_acc: 0.8973
# Epoch 2/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2213 - acc: 0.8959 - val_loss: 0.2169 - val_acc: 0.9113
# Epoch 3/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.2101 - acc: 0.9004 - val_loss: 0.2193 - val_acc: 0.9044
# Epoch 4/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2077 - acc: 0.9029 - val_loss: 0.2016 - val_acc: 0.8967
# Epoch 5/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2050 - acc: 0.9023 - val_loss: 0.2127 - val_acc: 0.8941
# Epoch 6/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1971 - acc: 0.9073 - val_loss: 0.1832 - val_acc: 0.9227
# Epoch 7/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1928 - acc: 0.9111 - val_loss: 0.1791 - val_acc: 0.9032
# Epoch 8/50
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1871 - acc: 0.9142 - val_loss: 0.2081 - val_acc: 0.9069
# Epoch 9/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1862 - acc: 0.9145 - val_loss: 0.2033 - val_acc: 0.9031
# Epoch 10/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1807 - acc: 0.9161 - val_loss: 0.2079 - val_acc: 0.9219
# Epoch 11/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1854 - acc: 0.9132 - val_loss: 0.1652 - val_acc: 0.9252
# Epoch 12/50
# 125/125 [==============================] - 4s 31ms/step - loss: 0.1713 - acc: 0.9247 - val_loss: 0.1789 - val_acc: 0.9143
# Epoch 13/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1679 - acc: 0.9255 - val_loss: 0.1636 - val_acc: 0.9298
# Epoch 14/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1673 - acc: 0.9275 - val_loss: 0.1718 - val_acc: 0.9070
# Epoch 15/50
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1644 - acc: 0.9258 - val_loss: 0.1755 - val_acc: 0.9291
# Epoch 16/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1626 - acc: 0.9295 - val_loss: 0.1889 - val_acc: 0.9244
# Epoch 17/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1644 - acc: 0.9293 - val_loss: 0.1691 - val_acc: 0.9284
# Epoch 18/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1575 - acc: 0.9313 - val_loss: 0.2122 - val_acc: 0.9124
# Epoch 19/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1587 - acc: 0.9324 - val_loss: 0.2038 - val_acc: 0.9229
# Epoch 20/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1605 - acc: 0.9307 - val_loss: 0.1744 - val_acc: 0.9217
# Epoch 21/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1608 - acc: 0.9305 - val_loss: 0.1809 - val_acc: 0.9287
# Epoch 22/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1518 - acc: 0.9356 - val_loss: 0.1371 - val_acc: 0.9438
# Epoch 23/50
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1561 - acc: 0.9332 - val_loss: 0.1558 - val_acc: 0.9208
# Epoch 24/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1490 - acc: 0.9353 - val_loss: 0.1240 - val_acc: 0.9527
# Epoch 25/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1482 - acc: 0.9361 - val_loss: 0.1365 - val_acc: 0.9454
# Epoch 26/50
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1481 - acc: 0.9373 - val_loss: 0.1366 - val_acc: 0.9424
# Epoch 27/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1481 - acc: 0.9371 - val_loss: 0.1728 - val_acc: 0.9192
# Epoch 28/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1430 - acc: 0.9399 - val_loss: 0.1803 - val_acc: 0.9332
# Epoch 29/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1424 - acc: 0.9413 - val_loss: 0.1246 - val_acc: 0.9521
# Epoch 30/50
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1437 - acc: 0.9389 - val_loss: 0.1822 - val_acc: 0.9244
# Epoch 31/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1446 - acc: 0.9384 - val_loss: 0.1392 - val_acc: 0.9454
# Epoch 32/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1425 - acc: 0.9408 - val_loss: 0.1138 - val_acc: 0.9556
# Epoch 33/50
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1446 - acc: 0.9391 - val_loss: 0.1373 - val_acc: 0.9486
# Epoch 34/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1367 - acc: 0.9422 - val_loss: 0.1252 - val_acc: 0.9502
# Epoch 35/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1427 - acc: 0.9403 - val_loss: 0.1460 - val_acc: 0.9390
# Epoch 36/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1399 - acc: 0.9404 - val_loss: 0.2161 - val_acc: 0.9063
# Epoch 37/50
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1366 - acc: 0.9426 - val_loss: 0.1589 - val_acc: 0.9286
# Epoch 38/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1325 - acc: 0.9443 - val_loss: 0.1689 - val_acc: 0.9324
# Epoch 39/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1356 - acc: 0.9421 - val_loss: 0.2193 - val_acc: 0.9182
# Epoch 40/50
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1435 - acc: 0.9397 - val_loss: 0.1590 - val_acc: 0.9270
# Epoch 41/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1352 - acc: 0.9425 - val_loss: 0.1439 - val_acc: 0.9447
# Epoch 42/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1426 - acc: 0.9397 - val_loss: 0.1480 - val_acc: 0.9394
# Epoch 43/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1323 - acc: 0.9461 - val_loss: 0.1176 - val_acc: 0.9550
# Epoch 44/50
# 125/125 [==============================] - 4s 32ms/step - loss: 0.1425 - acc: 0.9404 - val_loss: 0.1495 - val_acc: 0.9440
# Epoch 45/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1359 - acc: 0.9423 - val_loss: 0.1248 - val_acc: 0.9522
# Epoch 46/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1314 - acc: 0.9441 - val_loss: 0.1288 - val_acc: 0.9499
# Epoch 47/50
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1309 - acc: 0.9447 - val_loss: 0.1073 - val_acc: 0.9562
# Epoch 48/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1276 - acc: 0.9468 - val_loss: 0.1388 - val_acc: 0.9412
# Epoch 49/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1326 - acc: 0.9446 - val_loss: 0.2457 - val_acc: 0.9254
# Epoch 50/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1282 - acc: 0.9466 - val_loss: 0.1384 - val_acc: 0.9440

# %%
#à Predict the values from the validation dataset
y_pred = model.predict(X_test)


## Convert predictions classes to one hot vectors 
y_pred_classes = np.argmax(y_pred,axis = 1) 


## Convert validation observations to one hot vectors
y_true = np.argmax(y_test,axis = 1) 


## Compute the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes) 

## Compute loss and accuracy
test_loss, test_accuracy = model.evaluate(X_test,  y_test, verbose=2)

# %%
## Plot the confusion matrix

f,ax = plt.subplots(figsize=(10, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="summer_r", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
## Print accuracy and loss

print(f"Accuracy: {test_accuracy}\nLoss: {test_loss}")
# Out:
# Accuracy: 0.943999988079071
# Loss: 0.1384382756948471
